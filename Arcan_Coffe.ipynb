# %% [markdown]
# ### Features explanation
#
# |Feature| Explanation|
# |:-:|:---|
# |ContactId| Unique identifier for each contact in the database.
# |FirstName| The first name of the contact.
# |LastName| The last name of the contact.
# |FullName| The complete name of the contact, often a combination of first name and last name.
# |DateOfBirth| The contact's date of birth (Format: YYYY-MM-DD).
# |Gender| The gender of the contact (e.g., Male, Female, Other).
# |Email| The contact’s email address.
# |Telephone| The contact’s telephone number, including country and area codes.
# |PostCode| The postal code corresponding to the contact’s address.
# |StreetAddress| The street address where the contact resides.
# |City| The city where the contact resides.
# |State| The state or province where the contact resides.
# |Country| The country where the contact resides.
# |Created On| The date and time when the contact was added to the system (Format: YYYY-MM-DD HH:MM).
# |Headshot| A link or file reference to the contact’s headshot (image file).
# |Loyalty Tier| The loyalty tier assigned to the contact (e.g., Bronze, Silver, Gold), indicating their customer status or engagement level with the company.
# |Email Subscriber| Indicates whether the contact has subscribed to receive marketing emails (Yes/No).
# |Income| The estimated or reported income of the contact, usually represented annually.
# |Occupation| The contact's current occupation or job title.
# |CustomerSatisfaction| 'high', 'medium', 'low'

# %% [markdown]
# ### Data Load

# %%
import pandas as pd

base_df = pd.read_csv("https://filestransfer.blob.core.windows.net/ciad/Contact.txt", delimiter=',')

base_df.head(100)
# Out:
#      ContactId FirstName     LastName            FullName DateOfBirth  Gender  \
# 0   CNTID_1000     Abbie         Moss          Abbie Moss    5/8/1986  Female
# 1   CNTID_1001   Kenneth       Beraun      Beraun Kenneth    8/1/1974    Male
# 2   CNTID_1002   Anthony      Koteles     Acthony Koteles   8/28/1975    Male
# 3   CNTID_1003   Michael       Lauser      Michael Lauser    9/3/2006    Male
# 4   CNTID_1004   Richard       Nakada      Nakada Richard   7/30/1997    Male
# ..         ...       ...          ...                 ...         ...     ...
# 95  CNTID_1095    Edward  Bagdasarian  Edward Baadasarian    7/4/1980    Male
# 96  CNTID_1096    George       Rubero       Rubero George  11/16/1997    Male
# 97  CNTID_1097     Brian       Batson        Brian Batson   4/17/2008    Male
# 98  CNTID_1098    Joseph       Borell       Joseph Borell   7/27/2007    Male
# 99  CNTID_1099     Brian      Repasky       Brian Repasky   7/22/2002    Male
#
#                                            EMail             Telephone  \
# 0            abbie_moss@collinsreedandhoward.com     983.566.0706x9509
# 1                    kenneth_beraun@kimboyle.com          384.995.7852
# 2   anthony_koteles@crawfordsimmonsandgreene.com          569-626-5660
# 3                    michael_lauser@smithinc.com  001-811-506-2553x442
# 4        richard_nakada@jonesholmesandmooney.com          857-147-6531
# ..                                           ...                   ...
# 95     edward_bagdasarian@davisfoxandjohnson.com    (536)369-8888x3479
# 96      george_rubero@browncampbellandwarner.com      001-279-768-5125
# 97         brian_batson@jamesdudleyandgarcia.com      120-770-2761x538
# 98              joseph_borell@mendozaandsons.com     328-693-3726x1665
# 99          brian_repasky@munoztorresandward.com     004-544-6400x3941
#
#    PostCode                 StreetAddress          City           State  \
# 0     10753              129 Miller Plaza     Fairfield      California
# 1     40482          9720 William Prairie      Amarillo           Texas
# 2     28679  3958 Perez Centers Suite 216     Inglewood      California
# 3     93991             15091 Haynes Neck     Nashville       Tennessee
# 4     78389          3501 Thornton Radial   West Covina      California
# ..      ...                           ...           ...             ...
# 95    19161   561 Jonathan Inlet Apt. 481        Newark      New Jersey
# 96    82715  72407 James Forges Suite 289      Temecula      California
# 97    31903         046 Mclaughlin Street       Ontario      California
# 98    10339    395 Justin Knolls Apt. 890  Fayetteville  North Carolina
# 99    19444                2947 Gina Lock    Saint Paul       Minnesota
#
#    Country   CreatedOn                                           Headshot  \
# 0      USA   3/14/2017  https://filestransfer.blob.core.windows.net/de...
# 1      USA  12/23/2018  https://filestransfer.blob.core.windows.net/de...
# 2      USA   1/14/2019  https://filestransfer.blob.core.windows.net/de...
# 3      USA   1/17/2019  https://filestransfer.blob.core.windows.net/de...
# 4      USA   1/20/2019  https://filestransfer.blob.core.windows.net/de...
# ..     ...         ...                                                ...
# 95     USA   1/31/2019  https://filestransfer.blob.core.windows.net/de...
# 96     USA   1/31/2019  https://filestransfer.blob.core.windows.net/de...
# 97     USA   1/31/2019  https://filestransfer.blob.core.windows.net/de...
# 98     USA   1/31/2019  https://filestransfer.blob.core.windows.net/de...
# 99     USA   1/31/2019  https://filestransfer.blob.core.windows.net/de...
#
#    Loyalty Tier Email Subscriber         Income         Occupation  \
# 0          high              Yes  256414.112709  Software Engineer
# 1        medium              Yes   46732.467292            Teacher
# 2        medium              Yes   20000.000000            Teacher
# 3        medium               No   61917.706144            Teacher
# 4        medium               No   20000.000000            Teacher
# ..          ...              ...            ...                ...
# 95         high              Yes   72525.181509  Software Engineer
# 96       medium               No   20000.000000  Software Engineer
# 97       medium               No  124611.128425            Teacher
# 98       medium               No   20000.000000            Teacher
# 99       medium               No   27172.396843            Teacher
#
#    CustomerSatisfaction
# 0                  high
# 1                  high
# 2                  high
# 3                medium
# 4                medium
# ..                  ...
# 95                 high
# 96                  low
# 97               medium
# 98               medium
# 99               medium
#
# [100 rows x 20 columns]

# %%
print(base_df.columns)
# Out:
# Index(['ContactId', 'FirstName', 'LastName', 'FullName', 'DateOfBirth',
#        'Gender', 'EMail', 'Telephone', 'PostCode', 'StreetAddress', 'City',
#        'State', 'Country', 'CreatedOn', 'Headshot', 'Loyalty Tier',
#        'Email Subscriber', 'Income', 'Occupation', 'CustomerSatisfaction'],
#       dtype='object')

# %% [markdown]
# ### Exploratory Data Analysis

# %%
# Volume of the Dataset
num_records = len(base_df)
num_features = len(base_df.columns)

print(f"The dataset has {num_records} records and {num_features} features.")
# Out:
# The dataset has 5000 records and 20 features.

# %%
# Basic data exploration
print("Shape of the dataset:", base_df.shape)
# Out:
# Shape of the dataset: (5000, 20)

# %%
print("Data types:", base_df.dtypes)
# Out:
# Data types: ContactId                object
# FirstName                object
# LastName                 object
# FullName                 object
# DateOfBirth              object
# Gender                   object
# EMail                    object
# Telephone                object
# PostCode                 object
# StreetAddress            object
# City                     object
# State                    object
# Country                  object
# CreatedOn                object
# Headshot                 object
# Loyalty Tier             object
# Email Subscriber         object
# Income                  float64
# Occupation               object
# CustomerSatisfaction     object
# dtype: object

# %%
print("Missing values in each column:", base_df.isnull().sum())
# Out:
# Missing values in each column: ContactId               0
# FirstName               0
# LastName                0
# FullName                0
# DateOfBirth             1
# Gender                  0
# EMail                   0
# Telephone               0
# PostCode                0
# StreetAddress           0
# City                    0
# State                   0
# Country                 0
# CreatedOn               0
# Headshot                0
# Loyalty Tier            0
# Email Subscriber        0
# Income                  0
# Occupation              0
# CustomerSatisfaction    0
# dtype: int64

# %%
base_df.describe()
# Out:
#               Income
# count    5000.000000
# mean    82749.885539
# std     56499.410249
# min     20000.000000
# 25%     38197.144745
# 50%     73990.397082
# 75%    111254.694585
# max    419076.115889

# %% [markdown]
# ### Missing Values
# Since it was not found vas amounts of missing values we will be dropping the only feature that has them

# %%
# Dropping rows with missing values in critical columns
df_cleaned = base_df.dropna(subset=[
    "DateOfBirth"
])

# %% [markdown]
# #### Removing Unnecessary Columns
#
# We remove columns that do not contribute to the analysis or predictive models. By eliminating these irrelevant features, we streamline the dataset, reduce noise, and improve the efficiency of the data processing pipeline.

# %%
# List of columns to drop, the ones dropped 
columns_to_drop = ['DateOfBirth', 'Gender', 'EMail', 'Telephone', 'PostCode', 'StreetAddress', 'City', 'State', 'Country', 'CreatedOn', 'Headshot', 'Loyalty Tier', 'Email Subscriber', 'Income', 'Occupation', 'CustomerSatisfaction']

# Drop the columns from the DataFrame
df_cleaned = df_cleaned.drop(columns=columns_to_drop)

df_cleaned.head()
