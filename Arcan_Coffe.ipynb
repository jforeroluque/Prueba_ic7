# %% [markdown]
# ### Features explanation
#
# |Feature| Explanation|
# |:-:|:---|
# |ContactId| Unique identifier for each contact in the database.
# |FirstName| The first name of the contact.
# |LastName| The last name of the contact.
# |FullName| The complete name of the contact, often a combination of first name and last name.
# |DateOfBirth| The contact's date of birth (Format: YYYY-MM-DD).
# |Gender| The gender of the contact (e.g., Male, Female, Other).
# |Email| The contact’s email address.
# |Telephone| The contact’s telephone number, including country and area codes.
# |PostCode| The postal code corresponding to the contact’s address.
# |StreetAddress| The street address where the contact resides.
# |City| The city where the contact resides.
# |State| The state or province where the contact resides.
# |Country| The country where the contact resides.
# |Created On| The date and time when the contact was added to the system (Format: YYYY-MM-DD HH:MM).
# |Headshot| A link or file reference to the contact’s headshot (image file).
# |Loyalty Tier| The loyalty tier assigned to the contact (e.g., Bronze, Silver, Gold), indicating their customer status or engagement level with the company.
# |Email Subscriber| Indicates whether the contact has subscribed to receive marketing emails (Yes/No).
# |Income| The estimated or reported income of the contact, usually represented annually.
# |Occupation| The contact's current occupation or job title.
# |CustomerSatisfaction| 'high', 'medium', 'low'

# %% [markdown]
# ### Data Load

# %%
import pandas as pd

base_df = pd.read_csv("https://filestransfer.blob.core.windows.net/ciad/Contact.txt", delimiter=',')

base_df.head(50)
# Out:
#                                ContactId    FirstName   LastName  \
# 0                             CNTID_1000        Abbie       Moss
# 1                             CNTID_1001      Kenneth     Beraun
# 2                             CNTID_1002      Anthony    Koteles
# 3                             CNTID_1003      Michael     Lauser
# 4                             CNTID_1004      Richard     Nakada
# 5   f4444de5-664e-e911-a9ac-000d3a2d57c3       Robert    Kaucher
# 6                             CNTID_1006       Steven     Biondi
# 7                             CNTID_1007      Michael      Manni
# 8                             CNTID_1008      Michael     Glenna
# 9                             CNTID_1009        James      Eiler
# 10                            CNTID_1010       Thomas     Hawkey
# 11                            CNTID_1011         Paul  Hostetler
# 12                            CNTID_1012      William    Lowhorn
# 13                            CNTID_1013      William     Belles
# 14                            CNTID_1014      Anthony      Actis
# 15                            CNTID_1015       Edward  Dimalanta
# 16                            CNTID_1016       Ronald    Berning
# 17                            CNTID_1017       Daniel      Valme
# 18                            CNTID_1018      Michael   Muskthel
# 19                            CNTID_1019        Brian    Daricek
# 20                            CNTID_1020       Donald        Ham
# 21                            CNTID_1021      Richard   Durrance
# 22                            CNTID_1022       George      Deang
# 23                            CNTID_1023       Daniel      Prass
# 24                            CNTID_1024       Joseph      Brant
# 25                            CNTID_1025       Edward     Dobler
# 26                            CNTID_1026       Robert   Chalmers
# 27                            CNTID_1027      Richard        Aki
# 28                            CNTID_1028       Joseph    Studier
# 29                            CNTID_1029      Charles     Landes
# 30                            CNTID_1030       Donald  Woolhouse
# 31                            CNTID_1031      Richard      Crego
# 32                            CNTID_1032       Joseph   Colander
# 33                            CNTID_1033       Donald     Garica
# 34                            CNTID_1034        David     Fitser
# 35                            CNTID_1035  Christopher     Lemans
# 36                            CNTID_1036         Paul     Purves
# 37                            CNTID_1037       Edward     Daller
# 38                            CNTID_1038        Jason    Brazier
# 39                            CNTID_1039        David    Shenkle
# 40                            CNTID_1040         John     Loxton
# 41                            CNTID_1041  Christopher  Mcclurkan
# 42                            CNTID_1042       Joseph    Steinke
# 43                            CNTID_1043  Christopher     Veazey
# 44                            CNTID_1044        Brian   Balceiro
# 45                            CNTID_1045        David     Macall
# 46                            CNTID_1046        Brian    Feagley
# 47                            CNTID_1047      Kenneth    Lockamy
# 48                            CNTID_1048      Richard  Scatenato
# 49                            CNTID_1049      Richard    Swistak
#
#                  FullName DateOfBirth  Gender  \
# 0              Abbie Moss    5/8/1986  Female
# 1          Beraun Kenneth    8/1/1974    Male
# 2         Acthony Koteles   8/28/1975    Male
# 3          Michael Lauser    9/3/2006    Male
# 4          Nakada Richard   7/30/1997    Male
# 5          Kaucher Robert    3/8/1989    Male
# 6           Steven Biondi   9/20/2016    Male
# 7           Manni Michael    1/8/1979    Male
# 8          Michael Glenna    1/3/1998    Male
# 9             James Ecler    6/9/1984    Male
# 10          Thomas Hawiey    9/7/1972    Male
# 11         Paul Hostetler   6/26/2001    Male
# 12        Wiqliam Lowhorn   5/22/1982    Male
# 13         William Belles   6/28/1974    Male
# 14          Anthony Actis   10/6/1978    Male
# 15       Edward Dimalanta   10/3/1982    Male
# 16         Berning Ronald  11/12/2005    Male
# 17           Daniel Valme   4/12/1972    Male
# 18       Muskthel Michael  12/15/1977    Male
# 19          Bricn Daricek   5/24/1970    Male
# 20             Donald Ham  10/12/2000    Male
# 21       Richard Durrance   12/5/1979    Male
# 22           Gmorge Deang   4/22/1980    Male
# 23           Daliel Prass   2/28/1979    Male
# 24           Joseph Bmant   7/15/1992    Male
# 25          Edward Dobler  11/14/2015    Male
# 26        Robent Chalmers    5/2/1985    Male
# 27            Aki Richard   7/29/2015    Male
# 28         Joseph ntudier  10/18/1994    Male
# 29         Charles Laedes  10/10/2000    Male
# 30       Donalr Woolhouse   1/21/2000    Male
# 31          Crego Richard   8/23/1994    Male
# 32        Joseph Colander   3/17/1994    Male
# 33          Donald Garica   2/21/2006    Male
# 34           David Fitser   12/7/2000    Male
# 35     Christopher Lemans   3/13/2007    Male
# 36            Pall Purves   4/29/1972    Male
# 37          Edward Daller   5/23/2016    Male
# 38          Jason Brazier   9/18/2004    Male
# 39          David Shenkle   1/26/1997    Male
# 40            John Loxton    6/4/1995    Male
# 41  Christopher Mcclurkan    1/1/1990    Male
# 42         Joseph Steinke   2/20/1981    Male
# 43     Veazey Christopher    9/2/1977    Male
# 44         Brian Balceiro    9/7/1970    Male
# 45           Dcvid Macall   5/25/1984    Male
# 46          Brian Feagley   6/30/2014    Male
# 47        Lockamy Kenneth    5/8/1996    Male
# 48      Scatenato Richard   1/10/2011    Male
# 49        Richard Swistak   1/21/1987    Male
#
#                                            EMail               Telephone  \
# 0            abbie_moss@collinsreedandhoward.com       983.566.0706x9509
# 1                    kenneth_beraun@kimboyle.com            384.995.7852
# 2   anthony_koteles@crawfordsimmonsandgreene.com            569-626-5660
# 3                    michael_lauser@smithinc.com    001-811-506-2553x442
# 4        richard_nakada@jonesholmesandmooney.com            857-147-6531
# 5               robert_kaucher@stevenshansen.com              3347007637
# 6     steven_biondi@salazarbarnesandwilliams.com           (067)681-4908
# 7                 michael_manni@bautistacase.com     (837)364-9904x87242
# 8                   michael_glenna@carterplc.com               787699373
# 9           james_eiler@wilsonjohnsonandchan.com   001-849-959-4245x1045
# 10                    thomas_hawkey@allenltd.com            150-111-5060
# 11      paul_hostetler@whitebaxterandsimpson.com      145.729.6509x98208
# 12       william_lowhorn@daymurphyandherrera.com       655-423-0816x0881
# 13             william_belles@robbinsandsons.com      345-679-4618x02806
# 14              anthony_actis@ericksonwright.com       857-766-9037x7724
# 15    edward_dimalanta@leonardmillsandnewman.com      468-066-4361x36983
# 16               ronald_berning@gonzalezwang.com       659-478-7053x4515
# 17                daniel_valme@luceroschultz.com  001-446-175-3858x04144
# 18           michael_muskthel@bennettburnett.com            999-434-0395
# 19        brian_daricek@mendezlarsonandmoore.com     (851)743-3444x38523
# 20              donald_ham@hatfieldgutierrez.com        231.900.0749x963
# 21                 richard_durrance@drakellc.com      (601)050-4872x9400
# 22       george_deang@dodsondaltonandmathews.com      863-170-7317x93325
# 23       daniel_prass@stewartmooreandrosales.com      029-802-7724x45839
# 24                     joseph_brant@gomezltd.com            665-157-7561
# 25     edward_dobler@butlerwilliamsandturner.com            014-721-4131
# 26             robert_chalmers@nelsonandsons.com        656-965-6577x931
# 27                 richard_aki@leblancthomas.com           (477)304-7784
# 28      joseph_studier@hebertgrayandmartinez.com              6853895591
# 29        charles_landes@jonesjacksonandcole.com       194-245-2335x5051
# 30            donald_woolhouse@stephensgroup.com      (223)146-6176x9066
# 31               richard_crego@andersonjames.com              8981719509
# 32             joseph_colander@roachcampbell.com           (391)500-8955
# 33                  donald_garica@batessmith.com           (180)066-1404
# 34    david_fitser@hollandnovakandlivingston.com    001-133-138-7570x599
# 35  christopher_lemans@farleymilesandgarrett.com           (416)103-2568
# 36                  paul_purves@dickersonllc.com               693928238
# 37     edward_daller@halemartinezandrichards.com            455-714-7510
# 38                    jason_brazier@bakerinc.com           (965)944-2567
# 39                  david_shenkle@maxwellinc.com     (288)501-4478x83799
# 40         john_loxton@hollandthomasandramos.com    001-845-110-5203x923
# 41     christopher_mcclurkan@martinezandsons.com            722.970.8770
# 42              joseph_steinke@deansingleton.com              7852301348
# 43                christopher_veazey@kentinc.com       295-248-5519x1220
# 44                   brian_balceiro@ewingplc.com    001-354-045-6046x679
# 45     david_macall@robinsondiazanddougherty.com            828-720-0263
# 46    brian_feagley@kellystricklandandtaylor.com      915-186-8919x51321
# 47               kenneth_lockamy@sandovalplc.com    001-099-753-0154x185
# 48   richard_scatenato@mayerhillandchristian.com       (685)368-4055x250
# 49              richard_swistak@fosterhowell.com      529-574-5125x57485
#
#    PostCode                      StreetAddress              City  \
# 0     10753                   129 Miller Plaza         Fairfield
# 1     40482               9720 William Prairie          Amarillo
# 2     28679       3958 Perez Centers Suite 216         Inglewood
# 3     93991                  15091 Haynes Neck         Nashville
# 4     78389               3501 Thornton Radial       West Covina
# 5     47410      30112 Ricardo Greens Apt. 427        Costa Mesa
# 6     11513                873 Walker Motorway          Surprise
# 7     65361                     059 Green Port            Denton
# 8     34476         8963 Harris Keys Suite 743          Stockton
# 9     23103        168 Joseph Passage Apt. 791       Minneapolis
# 10    82352                 8701 Calvin Groves         Daly City
# 11    72928                 76466 Pamela Fords           Visalia
# 12    29334          526 Gray Freeway Apt. 976          Pearland
# 13    20728             09538 Carroll Overpass          Stamford
# 14    36330               36832 Jessica Bridge              Kent
# 15    74413                    9795 Alice Ramp           Fremont
# 16    64711         82523 Padilla Rue Apt. 803  West Valley City
# 17    90046         094 Parker Hollow Apt. 619       Springfield
# 18    25452                 269 Charles Stream         Worcester
# 19    85310      7633 Hernandez Club Suite 307     Overland Park
# 20    53955                29419 Michelle Wall     Sandy Springs
# 21    56173       17052 Joshua Knoll Suite 206            Pomona
# 22    51501                    548 Adams Flats          Temecula
# 23    23400       145 Hardin Valleys Suite 503           Anaheim
# 24    12368                  617 Parker Corner         New Haven
# 25    26860          745 Barrett Loaf Apt. 997          Chandler
# 26    95785                     338 Ruiz Mount       Victorville
# 27    30737    83349 Kevin Stravenue Suite 217             Vista
# 28    14637           4338 Lynch Way Suite 006        Santa Rosa
# 29    84223           01331 Shaw Path Apt. 023           Midland
# 30    32407                 23642 Rachel Lodge      Garden Grove
# 31    67878          0996 Gomez Trail Apt. 619     Moreno Valley
# 32    24243                  835 Dodson Spring            Austin
# 33    80329                   241 Andre Tunnel            Dayton
# 34    13974  0197 Christopher Gateway Apt. 832        Fort Worth
# 35    47794        6281 Paul Heights Suite 024         Knoxville
# 36    79651           217 Foster Pike Apt. 101             Miami
# 37    13792                  139 Wright Common             Davie
# 38    33991                   6071 Nelson Land             Plano
# 39    54631                89875 Stephen Ridge  Rancho Cucamonga
# 40    35695              95932 Vanessa Meadows          Columbus
# 41    82676       57109 Brandi Walks Suite 478           Everett
# 42    65404                     877 Kelsey Run            Austin
# 43    76365       6799 Joanne Street Suite 914            Renton
# 44    38283                 5627 Nguyen Greens         Santa Ana
# 45    74259                 2494 Spencer Knoll           Augusta
# 46    28745            4046 Simmons Throughway           Orlando
# 47    30071                    828 Amanda Keys        Fort Worth
# 48    57807                  05480 Harris Mill      Fayetteville
# 49    71701                  24292 Chaney Path         Cambridge
#
#              State Country   CreatedOn  \
# 0       California     USA   3/14/2017
# 1            Texas     USA  12/23/2018
# 2       California     USA   1/14/2019
# 3        Tennessee     USA   1/17/2019
# 4       California     USA   1/20/2019
# 5       California     USA   1/31/2019
# 6          Arizona     USA   1/31/2019
# 7            Texas     USA   1/31/2019
# 8       California     USA   1/31/2019
# 9        Minnesota     USA   1/31/2019
# 10      California     USA   1/31/2019
# 11      California     USA   1/31/2019
# 12           Texas     USA   1/31/2019
# 13     Connecticut     USA   1/31/2019
# 14      Washington     USA   1/31/2019
# 15      California     USA   1/31/2019
# 16            Utah     USA   1/31/2019
# 17        Illinois     USA   1/31/2019
# 18   Massachusetts     USA   1/31/2019
# 19          Kansas     USA   1/31/2019
# 20         Georgia     USA   1/31/2019
# 21      California     USA   1/31/2019
# 22      California     USA   1/31/2019
# 23      California     USA   1/31/2019
# 24     Connecticut     USA   1/31/2019
# 25         Arizona     USA   1/31/2019
# 26      California     USA   1/31/2019
# 27      California     USA   1/31/2019
# 28      California     USA   1/31/2019
# 29           Texas     USA   1/31/2019
# 30      California     USA   1/31/2019
# 31      California     USA   1/31/2019
# 32           Texas     USA   1/31/2019
# 33            Ohio     USA   1/31/2019
# 34           Texas     USA   1/31/2019
# 35       Tennessee     USA   1/31/2019
# 36         Florida     USA   1/31/2019
# 37         Florida     USA   1/31/2019
# 38           Texas     USA   1/31/2019
# 39      California     USA   1/31/2019
# 40         Georgia     USA   1/31/2019
# 41      Washington     USA   1/31/2019
# 42           Texas     USA   1/31/2019
# 43      Washington     USA   1/31/2019
# 44      California     USA   1/31/2019
# 45         Georgia     USA   1/31/2019
# 46         Florida     USA   1/31/2019
# 47           Texas     USA   1/31/2019
# 48  North Carolina     USA   1/31/2019
# 49   Massachusetts     USA   1/31/2019
#
#                                              Headshot Loyalty Tier  \
# 0   https://filestransfer.blob.core.windows.net/de...         high
# 1   https://filestransfer.blob.core.windows.net/de...       medium
# 2   https://filestransfer.blob.core.windows.net/de...       medium
# 3   https://filestransfer.blob.core.windows.net/de...       medium
# 4   https://filestransfer.blob.core.windows.net/de...       medium
# 5   https://filestransfer.blob.core.windows.net/de...          low
# 6   https://filestransfer.blob.core.windows.net/de...       medium
# 7   https://filestransfer.blob.core.windows.net/de...       medium
# 8   https://filestransfer.blob.core.windows.net/de...       medium
# 9   https://filestransfer.blob.core.windows.net/de...       medium
# 10  https://filestransfer.blob.core.windows.net/de...       medium
# 11  https://filestransfer.blob.core.windows.net/de...       medium
# 12  https://filestransfer.blob.core.windows.net/de...       medium
# 13  https://filestransfer.blob.core.windows.net/de...       medium
# 14  https://filestransfer.blob.core.windows.net/de...          low
# 15  https://filestransfer.blob.core.windows.net/de...       medium
# 16  https://filestransfer.blob.core.windows.net/de...       medium
# 17  https://filestransfer.blob.core.windows.net/de...         high
# 18  https://filestransfer.blob.core.windows.net/de...       medium
# 19  https://filestransfer.blob.core.windows.net/de...       medium
# 20  https://filestransfer.blob.core.windows.net/de...       medium
# 21  https://filestransfer.blob.core.windows.net/de...       medium
# 22  https://filestransfer.blob.core.windows.net/de...         high
# 23  https://filestransfer.blob.core.windows.net/de...          low
# 24  https://filestransfer.blob.core.windows.net/de...       medium
# 25  https://filestransfer.blob.core.windows.net/de...       medium
# 26  https://filestransfer.blob.core.windows.net/de...       medium
# 27  https://filestransfer.blob.core.windows.net/de...       medium
# 28  https://filestransfer.blob.core.windows.net/de...       medium
# 29  https://filestransfer.blob.core.windows.net/de...       medium
# 30  https://filestransfer.blob.core.windows.net/de...       medium
# 31  https://filestransfer.blob.core.windows.net/de...       medium
# 32  https://filestransfer.blob.core.windows.net/de...       medium
# 33  https://filestransfer.blob.core.windows.net/de...       medium
# 34  https://filestransfer.blob.core.windows.net/de...       medium
# 35  https://filestransfer.blob.core.windows.net/de...       medium
# 36  https://filestransfer.blob.core.windows.net/de...          low
# 37  https://filestransfer.blob.core.windows.net/de...       medium
# 38  https://filestransfer.blob.core.windows.net/de...       medium
# 39  https://filestransfer.blob.core.windows.net/de...       medium
# 40  https://filestransfer.blob.core.windows.net/de...       medium
# 41  https://filestransfer.blob.core.windows.net/de...       medium
# 42  https://filestransfer.blob.core.windows.net/de...       medium
# 43  https://filestransfer.blob.core.windows.net/de...       medium
# 44  https://filestransfer.blob.core.windows.net/de...       medium
# 45  https://filestransfer.blob.core.windows.net/de...       medium
# 46  https://filestransfer.blob.core.windows.net/de...       medium
# 47  https://filestransfer.blob.core.windows.net/de...       medium
# 48  https://filestransfer.blob.core.windows.net/de...       medium
# 49  https://filestransfer.blob.core.windows.net/de...       medium
#
#    Email Subscriber         Income         Occupation CustomerSatisfaction
# 0               Yes  256414.112709  Software Engineer                 high
# 1               Yes   46732.467292            Teacher                 high
# 2               Yes   20000.000000            Teacher                 high
# 3                No   61917.706144            Teacher               medium
# 4                No   20000.000000            Teacher               medium
# 5                No  151662.889395  Software Engineer                  low
# 6                No   49263.048955  Software Engineer                  low
# 7                No   20000.000000            Teacher                  low
# 8                No   23242.992770            Teacher               medium
# 9                No   42136.513844  Software Engineer                 high
# 10              Yes   84403.539309            Teacher               medium
# 11               No   20000.000000            Teacher                  low
# 12               No   20000.000000  Software Engineer                  low
# 13               No   20000.000000  Software Engineer               medium
# 14              Yes  314676.955271             Doctor               medium
# 15               No   98571.609197            Teacher               medium
# 16               No   29464.344850            Teacher                 high
# 17              Yes  180350.642742  Software Engineer                 high
# 18               No  115968.954126            Teacher                 high
# 19               No   20000.000000            Teacher               medium
# 20               No   20000.000000  Software Engineer               medium
# 21              Yes   20000.000000  Software Engineer               medium
# 22              Yes  147386.595387  Software Engineer                 high
# 23              Yes  167783.319499  Software Engineer                  low
# 24               No  124940.203527            Teacher               medium
# 25              Yes   73971.451817            Teacher               medium
# 26              Yes   83322.434066            Teacher               medium
# 27               No   20000.000000            Teacher               medium
# 28               No   58506.288169  Software Engineer                  low
# 29               No  105454.087947            Student                  low
# 30               No   20000.000000            Teacher               medium
# 31               No   68313.835901            Teacher               medium
# 32               No   56694.344382            Teacher               medium
# 33              Yes  166241.356219  Software Engineer               medium
# 34               No   84056.457296            Teacher                  low
# 35               No  111318.189504            Teacher                 high
# 36               No  151367.116262  Software Engineer               medium
# 37               No  101025.598356            Teacher                 high
# 38              Yes  112039.672234  Software Engineer               medium
# 39              Yes   20000.000000            Teacher               medium
# 40               No  133071.364518  Software Engineer               medium
# 41              Yes  109068.280855  Software Engineer                 high
# 42               No   63430.395343  Software Engineer               medium
# 43               No   20000.000000            Teacher               medium
# 44               No   33872.196143            Teacher                  low
# 45              Yes  115085.965932  Software Engineer                 high
# 46               No   79525.298945            Teacher                 high
# 47               No   20000.000000            Teacher                  low
# 48               No   91022.298213  Software Engineer               medium
# 49               No   34862.842894            Teacher               medium

# %%
print(base_df.columns)
# Out:
# Index(['ContactId', 'FirstName', 'LastName', 'FullName', 'DateOfBirth',
#        'Gender', 'EMail', 'Telephone', 'PostCode', 'StreetAddress', 'City',
#        'State', 'Country', 'CreatedOn', 'Headshot', 'Loyalty Tier',
#        'Email Subscriber', 'Income', 'Occupation', 'CustomerSatisfaction'],
#       dtype='object')

# %% [markdown]
# ### Exploratory Data Analysis

# %%
# Volume of the Dataset
num_records = len(base_df)
num_features = len(base_df.columns)

print(f"The dataset has {num_records} records and {num_features} features.")
# Out:
# The dataset has 5000 records and 20 features.

# %%
print("Data types:", base_df.dtypes)
# Out:
# Data types: ContactId                object
# FirstName                object
# LastName                 object
# FullName                 object
# DateOfBirth              object
# Gender                   object
# EMail                    object
# Telephone                object
# PostCode                 object
# StreetAddress            object
# City                     object
# State                    object
# Country                  object
# CreatedOn                object
# Headshot                 object
# Loyalty Tier             object
# Email Subscriber         object
# Income                  float64
# Occupation               object
# CustomerSatisfaction     object
# dtype: object

# %%
print("Missing values in each column:", base_df.isnull().sum())
# Out:
# Missing values in each column: ContactId               0
# FirstName               0
# LastName                0
# FullName                0
# DateOfBirth             1
# Gender                  0
# EMail                   0
# Telephone               0
# PostCode                0
# StreetAddress           0
# City                    0
# State                   0
# Country                 0
# CreatedOn               0
# Headshot                0
# Loyalty Tier            0
# Email Subscriber        0
# Income                  0
# Occupation              0
# CustomerSatisfaction    0
# dtype: int64

# %%
base_df.describe()
# Out:
#               Income
# count    5000.000000
# mean    82749.885539
# std     56499.410249
# min     20000.000000
# 25%     38197.144745
# 50%     73990.397082
# 75%    111254.694585
# max    419076.115889

# %% [markdown]
# ### Missing Values
# Since it was not found vas amounts of missing values we will be dropping the only feature that has them

# %%
# Dropping rows with missing values in critical columns
df_cleaned = base_df.dropna(subset=[
    "DateOfBirth"
])

# %% [markdown]
# #### Removing Unnecessary Columns
#
# We remove columns that do not contribute to the analysis or predictive models. By eliminating these irrelevant features, we streamline the dataset, reduce noise, and improve the efficiency of the data processing pipeline.

# %%
# List of columns to drop, the ones dropped 
columns_to_drop = ['ContactId', 'FirstName', 'LastName', 'FullName', 'Gender', 'EMail', 'Telephone', 'PostCode', 'StreetAddress', 'Headshot', 'Country']

df_cleaned = df_cleaned.drop(columns=columns_to_drop)

df_cleaned.head()
# Out:
#   DateOfBirth         City       State   CreatedOn Loyalty Tier  \
# 0    5/8/1986    Fairfield  California   3/14/2017         high
# 1    8/1/1974     Amarillo       Texas  12/23/2018       medium
# 2   8/28/1975    Inglewood  California   1/14/2019       medium
# 3    9/3/2006    Nashville   Tennessee   1/17/2019       medium
# 4   7/30/1997  West Covina  California   1/20/2019       medium
#
#   Email Subscriber         Income         Occupation CustomerSatisfaction
# 0              Yes  256414.112709  Software Engineer                 high
# 1              Yes   46732.467292            Teacher                 high
# 2              Yes   20000.000000            Teacher                 high
# 3               No   61917.706144            Teacher               medium
# 4               No   20000.000000            Teacher               medium

# %% [markdown]
# ### Fix Data types

# %%
df_cleaned['DateOfBirth'] = pd.to_datetime(base_df['DateOfBirth'], errors='coerce')
df_cleaned['CreatedOn'] = pd.to_datetime(base_df['CreatedOn'], errors='coerce')

# %%
df_cleaned['Loyalty Tier'] = base_df['Loyalty Tier'].astype('category')
df_cleaned['CustomerSatisfaction'] = base_df['CustomerSatisfaction'].astype('category')
df_cleaned['Email Subscriber'] = base_df['Email Subscriber'].astype('category')

# %%
df_cleaned.info
# Out:
# <bound method DataFrame.info of      DateOfBirth         City       State  CreatedOn Loyalty Tier  \
# 0     1986-05-08    Fairfield  California 2017-03-14         high
# 1     1974-08-01     Amarillo       Texas 2018-12-23       medium
# 2     1975-08-28    Inglewood  California 2019-01-14       medium
# 3     2006-09-03    Nashville   Tennessee 2019-01-17       medium
# 4     1997-07-30  West Covina  California 2019-01-20       medium
# ...          ...          ...         ...        ...          ...
# 4994  1983-07-06      El Paso       Texas 2019-01-31       medium
# 4995  1981-04-20        Davie     Florida 2019-01-31       medium
# 4996  1970-12-25      Lincoln    Nebraska 2019-01-31       medium
# 4997  2014-12-04    Green Bay   Wisconsin 2019-01-31       medium
# 4998  1983-12-04      Toronto     Ontario 2018-03-22       medium
#
#      Email Subscriber         Income         Occupation CustomerSatisfaction
# 0                 Yes  256414.112709  Software Engineer                 high
# 1                 Yes   46732.467292            Teacher                 high
# 2                 Yes   20000.000000            Teacher                 high
# 3                  No   61917.706144            Teacher               medium
# 4                  No   20000.000000            Teacher               medium
# ...               ...            ...                ...                  ...
# 4994               No   57950.026863            Teacher               medium
# 4995               No   20000.000000            Teacher                 high
# 4996               No   38995.563316            Teacher               medium
# 4997              Yes   21566.980225            Teacher               medium
# 4998              Yes   46254.292387            Teacher                 high
#
# [4999 rows x 9 columns]>

# %%
df_cleaned.head(20)
# Out:
#    DateOfBirth              City          State  CreatedOn Loyalty Tier  \
# 0   1986-05-08         Fairfield     California 2017-03-14         high
# 1   1974-08-01          Amarillo          Texas 2018-12-23       medium
# 2   1975-08-28         Inglewood     California 2019-01-14       medium
# 3   2006-09-03         Nashville      Tennessee 2019-01-17       medium
# 4   1997-07-30       West Covina     California 2019-01-20       medium
# 5   1989-03-08        Costa Mesa     California 2019-01-31          low
# 6   2016-09-20          Surprise        Arizona 2019-01-31       medium
# 7   1979-01-08            Denton          Texas 2019-01-31       medium
# 8   1998-01-03          Stockton     California 2019-01-31       medium
# 9   1984-06-09       Minneapolis      Minnesota 2019-01-31       medium
# 10  1972-09-07         Daly City     California 2019-01-31       medium
# 11  2001-06-26           Visalia     California 2019-01-31       medium
# 12  1982-05-22          Pearland          Texas 2019-01-31       medium
# 13  1974-06-28          Stamford    Connecticut 2019-01-31       medium
# 14  1978-10-06              Kent     Washington 2019-01-31          low
# 15  1982-10-03           Fremont     California 2019-01-31       medium
# 16  2005-11-12  West Valley City           Utah 2019-01-31       medium
# 17  1972-04-12       Springfield       Illinois 2019-01-31         high
# 18  1977-12-15         Worcester  Massachusetts 2019-01-31       medium
# 19  1970-05-24     Overland Park         Kansas 2019-01-31       medium
#
#    Email Subscriber         Income         Occupation CustomerSatisfaction
# 0               Yes  256414.112709  Software Engineer                 high
# 1               Yes   46732.467292            Teacher                 high
# 2               Yes   20000.000000            Teacher                 high
# 3                No   61917.706144            Teacher               medium
# 4                No   20000.000000            Teacher               medium
# 5                No  151662.889395  Software Engineer                  low
# 6                No   49263.048955  Software Engineer                  low
# 7                No   20000.000000            Teacher                  low
# 8                No   23242.992770            Teacher               medium
# 9                No   42136.513844  Software Engineer                 high
# 10              Yes   84403.539309            Teacher               medium
# 11               No   20000.000000            Teacher                  low
# 12               No   20000.000000  Software Engineer                  low
# 13               No   20000.000000  Software Engineer               medium
# 14              Yes  314676.955271             Doctor               medium
# 15               No   98571.609197            Teacher               medium
# 16               No   29464.344850            Teacher                 high
# 17              Yes  180350.642742  Software Engineer                 high
# 18               No  115968.954126            Teacher                 high
# 19               No   20000.000000            Teacher               medium

# %%
print("Data types:", df_cleaned.dtypes)
# Out:
# Data types: DateOfBirth             datetime64[ns]
# City                            object
# State                           object
# CreatedOn               datetime64[ns]
# Loyalty Tier                  category
# Email Subscriber              category
# Income                         float64
# Occupation                      object
# CustomerSatisfaction          category
# dtype: object

# %%
# Set the count to distinct values in each categorical feature
for col_name in ['City', 'State', 'Loyalty Tier', 'Email Subscriber', 'Occupation', 'CustomerSatisfaction']:
    print(f"\nDistinct counts for {col_name}:")
    print(df_cleaned[col_name].value_counts())
# Out:
# Distinct counts for City:
# City
# Springfield    48
# Columbia       34
# Peoria         31
# Glendale       30
# Rochester      30
#                ..
# Miami           8
# Milwaukee       7
# Anchorage       7
# Raleigh         7
# Toronto         1
# Name: count, Length: 300, dtype: int64
#
# Distinct counts for State:
# State
# California              1186
# Texas                    608
# Florida                  359
# Colorado                 189
# Arizona                  175
# Georgia                  140
# North Carolina           139
# Washington               130
# Illinois                 128
# Virginia                 111
# New Jersey               110
# Michigan                 102
# Tennessee                 95
# Ohio                      93
# Connecticut               92
# Oregon                    92
# Kansas                    88
# Alabama                   88
# Massachusetts             85
# New York                  75
# Nevada                    70
# Louisiana                 65
# Utah                      63
# Indiana                   62
# Oklahoma                  61
# Minnesota                 60
# Pennsylvania              55
# Missouri                  55
# Iowa                      49
# Wisconsin                 45
# South Carolina            44
# New Mexico                38
# Nebraska                  37
# Kentucky                  26
# District of Columbia      22
# New Hampshire             20
# Hawaii                    20
# Maryland                  18
# Montana                   18
# Idaho                     17
# North Dakota              15
# Rhode Island              13
# Mississippi               13
# Arkansas                  11
# South Dakota               9
# Alaska                     7
# Ontario                    1
# Name: count, dtype: int64
#
# Distinct counts for Loyalty Tier:
# Loyalty Tier
# medium    4036
# low        520
# high       443
# Name: count, dtype: int64
#
# Distinct counts for Email Subscriber:
# Email Subscriber
# No     3365
# Yes    1634
# Name: count, dtype: int64
#
# Distinct counts for Occupation:
# Occupation
# Teacher               2595
# Software Engineer     2191
# Student                117
# Investment Banking      76
# Doctor                  20
# Name: count, dtype: int64
#
# Distinct counts for CustomerSatisfaction:
# CustomerSatisfaction
# medium    2499
# low       1320
# high      1180
# Name: count, dtype: int64

# %%
# Check for duplicates in the df_cleaned dataframe
duplicates = df_cleaned[df_cleaned.duplicated()]

# Display the duplicate rows, if any
if not duplicates.empty:
    print("Duplicate rows found:")
    print(duplicates)
else:
    print("No duplicate rows found.")
# Out:
# No duplicate rows found.

# %% [markdown]
# ## Feature Exploration

# %%
import matplotlib.pyplot as plt

loyalty_tier_counts = df_cleaned['Loyalty Tier'].value_counts()

# Plotting the distribution of Loyalty Tier
plt.figure(figsize=(8, 6))
loyalty_tier_counts.plot(kind='bar', color='skyblue')

# Adding titles and labels
plt.title('Distribution of Loyalty Tier', fontsize=14)
plt.xlabel('Loyalty Tier', fontsize=12)
plt.ylabel('Number of Customers', fontsize=12)

# Show plot
plt.xticks(rotation=45)
plt.show()

# %%
customer_satisfaction_counts = df_cleaned['CustomerSatisfaction'].value_counts()

# Plotting the distribution 
plt.figure(figsize=(8, 6))
customer_satisfaction_counts.plot(kind='bar', color='skyblue')

# Adding titles and labels
plt.title('Distribution of Customer Satisfaction', fontsize=14)
plt.xlabel('Satisfaction Tier', fontsize=12)
plt.ylabel('Number of Customers', fontsize=12)

# Show plot
plt.xticks(rotation=45)
plt.show()

# %%
import seaborn as sns

# Plotting the distribution of Income
plt.figure(figsize=(8, 6))
sns.histplot(df_cleaned['Income'], kde=True, color='green')

# Adding titles and labels
plt.title('Distribution of Income', fontsize=14)
plt.xlabel('Income', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

# Show plot
plt.show()

# %%
from datetime import datetime

# Calculate age by subtracting 'DateOfBirth' from today's date
current_date = datetime.now()
df_cleaned['Age'] = df_cleaned['DateOfBirth'].apply(lambda dob: current_date.year - dob.year - ((current_date.month, current_date.day) < (dob.month, dob.day)))

# Plotting the distribution of Age
plt.figure(figsize=(8, 6))
sns.histplot(df_cleaned['Age'], kde=True, color='purple')

# Adding titles and labels
plt.title('Distribution of Customer Age', fontsize=14)
plt.xlabel('Age', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

# Show plot
plt.show()

# %%
# Ensure 'CreatedOn' is in datetime format
df_cleaned['CreatedOn'] = pd.to_datetime(df_cleaned['CreatedOn'])

# Calculate tenure in days
df_cleaned['Tenure'] = (current_date - df_cleaned['CreatedOn']).dt.days

# Plotting a histogram and density plot of Customer Tenure
plt.figure(figsize=(8, 6))
sns.histplot(df_cleaned['Tenure'], kde=True, color='blue')

# Adding titles and labels
plt.title('Distribution of Customer Tenure', fontsize=14)
plt.xlabel('Tenure (Days)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

# Show plot
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df_cleaned['Tenure'], kde=True, color='blue')

# Adding titles and labels
plt.title('Distribution of Customer Tenure', fontsize=14)
plt.xlabel('Tenure (Days)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

# Set y-axis limit to zoom in on the plot
plt.ylim(0, 5000)

# Show plot
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df_cleaned['Tenure'], kde=True, color='blue')

# Adding titles and labels
plt.title('Distribution of Customer Tenure (Logarithmic Scale)', fontsize=14)
plt.xlabel('Tenure (Days)', fontsize=12)
plt.ylabel('Frequency (Log Scale)', fontsize=12)

# Set y-axis to log scale
plt.yscale('log')

# Show plot
plt.show()

# %%
# Check the min and max dates in the CreatedOn feature
print("Minimum CreatedOn Date:", df_cleaned['CreatedOn'].min())
print("Maximum CreatedOn Date:", df_cleaned['CreatedOn'].max())
# Out:
# Minimum CreatedOn Date: 2017-03-14 00:00:00
# Maximum CreatedOn Date: 2019-01-31 00:00:00

# %%
# Check the first few rows of Tenure to verify the calculation
df_cleaned['Tenure'] = (current_date - df_cleaned['CreatedOn']).dt.days
df_cleaned[['CreatedOn', 'Tenure']].head(5000)
# Out:
#       CreatedOn  Tenure
# 0    2017-03-14    2770
# 1    2018-12-23    2121
# 2    2019-01-14    2099
# 3    2019-01-17    2096
# 4    2019-01-20    2093
# ...         ...     ...
# 4994 2019-01-31    2082
# 4995 2019-01-31    2082
# 4996 2019-01-31    2082
# 4997 2019-01-31    2082
# 4998 2018-03-22    2397
#
# [4999 rows x 2 columns]

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df_cleaned['CreatedOn'], kde=True, color='green')

# Adding titles and labels
plt.title('Distribution of CreatedOn Dates', fontsize=14)
plt.xlabel('CreatedOn Date', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

# Show plot
plt.show()
